# %%
import os
import cv2
import numpy as np

def load_images_from_folder(folder):
    images = []
    labels = []
    for class_folder in os.listdir(folder):
        class_path = os.path.join(folder, class_folder)
        if os.path.isdir(class_path):
            for filename in os.listdir(class_path):
                img_path = os.path.join(class_path, filename)
                img = cv2.imread(img_path)
                img = cv2.resize(img, (224, 224))  # Resize images
                if img is not None:
                    images.append(img)
                    labels.append(class_folder)
    return np.array(images), np.array(labels)

data_folder = "./Traffic Sign/DATA"
images, labels = load_images_from_folder(data_folder)

# %%
def extract_low_level_features(images):
    features = []
    for img in images:
        gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
        # Apply your low-level feature extraction techniques (e.g., edges, textures)
        # For example, you can use Canny edge detection:
        edges = cv2.Canny(gray, 100, 200)
        features.append(edges.flatten())
    return np.array(features)

low_level_features = extract_low_level_features(images)

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

datagen = ImageDataGenerator(
    rotation_range=15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    shear_range=0.01,
    zoom_range=[0.9, 1.25],
    horizontal_flip=True,
    vertical_flip=False,
    fill_mode='reflect',
    data_format='channels_last'
)

datagen.fit(X_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 15
#       1 from tensorflow.keras.preprocessing.image import ImageDataGenerator
#       3 datagen = ImageDataGenerator(
#       4     rotation_range=15,
#       5     width_shift_range=0.1,
#    (...)
#      12     data_format='channels_last'
#      13 )
# ---> 15 datagen.fit(X_train)
#
# NameError: name 'X_train' is not defined

# %%
def preprocess_image(image):
    image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)  # Convert to grayscale
    image = cv2.equalizeHist(image)  # Histogram equalization
    image = cv2.GaussianBlur(image, (5, 5), 0)  # Gaussian denoising
    image = image / 255.0  # Normalization
    return image

X_train = np.array([preprocess_image(img) for img in X_train])
X_test = np.array([preprocess_image(img) for img in X_test])

# %%
from skimage.feature import hog

def extract_hog_features(images):
    hog_features = []
    for image in images:
        features, _ = hog(image, orientations=9, pixels_per_cell=(8, 8), cells_per_block=(2, 2), block_norm='L2', visualize=True)
        hog_features.append(features)
    return np.array(hog_features)

X_train_hog = extract_hog_features(X_train)
X_test_hog = extract_hog_features(X_test)

# %%
from skimage.feature import local_binary_pattern

def extract_lbp_features(images):
    lbp_features = []
    radius = 3
    n_points = 8 * radius
    for image in images:
        lbp = local_binary_pattern(image, n_points, radius, method='uniform')
        hist, _ = np.histogram(lbp, bins=np.arange(0, n_points + 3), range=(0, n_points + 2))
        hist = hist.astype('float')
        hist /= hist.sum()  # Normalize the histogram
        lbp_features.append(hist)
    return np.array(lbp_features)

X_train_lbp = extract_lbp_features(X_train)
X_test_lbp = extract_lbp_features(X_test)

# %%
import tensorflow as tf
from tensorflow.keras.applications.vgg16 import VGG16
from tensorflow.keras.applications.vgg16 import preprocess_input

def extract_high_level_features(images):
    model = VGG16(weights='imagenet', include_top=False)
    features = []
    for img in images:
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)  # VGG expects RGB images
        img = cv2.resize(img, (224, 224))
        img = preprocess_input(img)
        feature = model.predict(np.expand_dims(img, axis=0))
        features.append(feature.flatten())
    return np.array(features)

high_level_features = extract_high_level_features(images)
# Out:
# ...
# 58889256/58889256 ━━━━━━━━━━━━━━━━━━━━ 77s 1us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 916ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 710ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 599ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 545ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 562ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 550ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 594ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 559ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 573ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 613ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 559ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 529ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 542ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 585ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 534ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 545ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 614ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 578ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 558ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 614ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 738ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 618ms/step
# ...

# %%
from sklearn.decomposition import PCA

def apply_pca(features, n_components=100):
    pca = PCA(n_components=n_components)
    reduced_features = pca.fit_transform(features)
    return reduced_features

reduced_features = apply_pca(high_level_features)

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as LDA

lda = LDA(n_components=100)
X_train_lda = lda.fit_transform(X_train_cnn, y_train)
X_test_lda = lda.transform(X_test_cnn)

# %%
from sklearn.decomposition import FastICA

ica = FastICA(n_components=100)
X_train_ica = ica.fit_transform(X_train_cnn)
X_test_ica = ica.transform(X_test_cnn)

# %%
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score

X_train, X_test, y_train, y_test = train_test_split(reduced_features, labels, test_size=0.2, random_state=42)

svm = SVC(kernel='linear')
svm.fit(X_train, y_train)

y_pred = svm.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 1.0

# %%
import cv2
import numpy as np
import os
from skimage import transform

def augment_images(image_folder, target_folder, target_count_per_class):
    for class_folder in os.listdir(image_folder):
        class_path = os.path.join(image_folder, class_folder)
        if os.path.isdir(class_path):
            images = []
            for filename in os.listdir(class_path):
                img_path = os.path.join(class_path, filename)
                img = cv2.imread(img_path)
                images.append(img)
            while len(images) < target_count_per_class:
                # Randomly select an image from the class
                img = images[np.random.randint(0, len(images))]
                # Apply augmentation techniques
                if np.random.choice([True, False]):
                    img = cv2.flip(img, 1)  # Horizontal flip
                if np.random.choice([True, False]):
                    angle = np.random.uniform(-30, 30)  # Rotation
                    img = transform.rotate(img, angle)
                if np.random.choice([True, False]):
                    scale = np.random.uniform(0.8, 1.2)  # Scaling
                    img = cv2.resize(img, None, fx=scale, fy=scale)
                # Save the augmented image
                new_filename = f"{filename.split('.')[0]}_augmented.png"
                new_img_path = os.path.join(target_folder, class_folder, new_filename)
                cv2.imwrite(new_img_path, img)
                images.append(img)

image_folder = "./Traffic Sign/DATA"
target_folder = "./Traffic Sign/RES"
target_count_per_class = 100  # Specify the target number of images per class
augment_images(image_folder, target_folder, target_count_per_class)

# %%
def normalize_image(image):
    normalized_image = cv2.normalize(image, None, alpha=0, beta=1, norm_type=cv2.NORM_MINMAX, dtype=cv2.CV_32F)
    return normalized_image

# %%
def equalize_histogram(image):
    gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    equalized_image = cv2.equalizeHist(gray_image)
    return equalized_image

# %%
def denoise_image(image):
    denoised_image = cv2.medianBlur(image, 5)  # Apply median blur with kernel size 5
    return denoised_image

# %%
def resize_image(image, target_size):
    resized_image = cv2.resize(image, target_size)
    return resized_image

def apply_gaussian_blur(image):
    blurred_image = cv2.GaussianBlur(image, (5, 5), 0)
    return blurred_image

def enhance_edges(image):
    gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    edges = cv2.Canny(gray_image, 100, 200)
    return edges

# %%
import cv2
from skimage.feature import hog
from skimage import exposure

def extract_hog_features(image):
    # Convert the image to grayscale
    gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    # Compute the HOG features
    features, hog_image = hog(gray_image, orientations=9, pixels_per_cell=(8, 8),
                               cells_per_block=(2, 2), visualize=True, block_norm='L2-Hys')
    # Rescale the HOG image for better visualization
    hog_image_rescaled = exposure.rescale_intensity(hog_image, in_range=(0, 10))
    return features, hog_image_rescaled

# %%
def extract_lbp_features(image):
    # Convert the image to grayscale
    gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    # Compute the LBP features
    lbp = cv2.LBP_create()
    features = lbp.compute(gray_image)
    return features.flatten()

# %%
from tensorflow.keras.applications import VGG16
from tensorflow.keras.applications.vgg16 import preprocess_input
from tensorflow.keras.models import Model

base_model = VGG16(weights='imagenet', include_top=False)

# %%
from sklearn import svm

# Linear kernel
clf_linear = svm.SVC(kernel='linear')
clf_linear.fit(X_train, y_train)

# Polynomial kernel
clf_poly = svm.SVC(kernel='poly', degree=3)  # degree is the degree of the polynomial kernel
clf_poly.fit(X_train, y_train)

# RBF kernel
clf_rbf = svm.SVC(kernel='rbf', gamma='scale')  # gamma is the kernel coefficient for RBF
clf_rbf.fit(X_train, y_train)
# Out:
# SVC()

# %%
from sklearn.metrics import accuracy_score

y_pred_linear = clf_linear.predict(X_test)
accuracy_linear = accuracy_score(y_test, y_pred_linear)

y_pred_poly = clf_poly.predict(X_test)
accuracy_poly = accuracy_score(y_test, y_pred_poly)

y_pred_rbf = clf_rbf.predict(X_test)
accuracy_rbf = accuracy_score(y_test, y_pred_rbf)

print("Accuracy (Linear Kernel):", accuracy_linear)
print("Accuracy (Polynomial Kernel):", accuracy_poly)
print("Accuracy (RBF Kernel):", accuracy_rbf)
# Out:
# Accuracy (Linear Kernel): 1.0
# Accuracy (Polynomial Kernel): 0.9685714285714285
# Accuracy (RBF Kernel): 1.0
